# %% [markdown]
# Industry-Oriented Marketing Campaign Performance Analysis

# %% [markdown]
# Necessary imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %% [markdown]
# Data injetion, cleaning and preprocessing

# %%
# Load the dataset
data = pd.read_csv(r"C:\Users\Jasmine Rahaman\Desktop\vscode\jasmine\DataScienceProjects\nykaa_campaign_data.csv")

# convert the data into pandas dataframe
df = pd.DataFrame(data)

# Check for missing values
#print(df.isnull().sum())

# df.describe()

df.info()        #describing the dataframe, no null values found, no duplicates found
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55555 entries, 0 to 55554
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Campaign_ID       55555 non-null  object
#  1   Campaign_Type     55555 non-null  object
#  2   Target_Audience   55555 non-null  object
#  3   Duration          55555 non-null  int64
#  4   Channel_Used      55555 non-null  object
#  5   Impressions       55555 non-null  int64
#  6   Clicks            55555 non-null  int64
#  7   Leads             55555 non-null  int64
#  8   Conversions       55555 non-null  int64
#  9   Revenue           55555 non-null  int64
#  10  Acquisition_Cost  55555 non-null  float64
#  11  ROI               55555 non-null  float64
#  12  Language          55555 non-null  object
#  13  Engagement_Score  55555 non-null  float64
#  14  Customer_Segment  55555 non-null  object
#  15  Date              55555 non-null  object
# ...

# %% [markdown]
# Exploratory Data Analysis

# %%
#Campaign_Type
# df["Campaign_Type"].value_counts()
#sns.countplot(x='Campaign_Type',data=df)

#Target_Audience
# df['Target_Audience'].value_counts()
#sns.countplot(x='Target_Audience',data=df)
# plt.figure(figsize=(12,6))
# sns.barplot(x=df['Target_Audience'].value_counts().values, 
#            y=df['Target_Audience'].value_counts().index)
# plt.xticks(rotation=90)   # rotate age labels
# plt.ylabel("Count of Customers")
# plt.xlabel("Target_Audience")
# plt.title("Target_Audience of Customers")
# plt.show()

#Duration
# df['Duration'].value_counts()
#sns.countplot(x='Duration',data=df)

#Channel_Used (Instagram, email, whatsapp, youtube)
# df['Channel_Used'].value_counts()
# plt.figure(figsize=(12,6))
# sns.barplot(x=df['Channel_Used'].head(20).value_counts().index,y=df['Channel_Used'].head(20).value_counts().values)
# plt.xticks(rotation=90)
# plt.xlabel("Channel_Used")
# plt.ylabel("Count of Customer")
# plt.title("Chennel_used for promotion")
# plt.show()

#Impressions
df['Impressions'].value_counts().head(20)
#sns.countplot(x='Impressions'.head(20),data=df)

df['Clicks'].value_counts()

df['Leads'].value_counts()

df['Conversions'].value_counts()

df['Revenue'].value_counts()

df['']
# Out:
# Revenue
# 86940      6
# 107100     6
# 125664     5
# 199584     5
# 201096     5
#           ..
# 162945     1
# 792728     1
# 383640     1
# 194051     1
# 1046247    1
# Name: count, Length: 49394, dtype: int64
